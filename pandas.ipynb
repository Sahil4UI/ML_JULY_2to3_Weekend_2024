# %%
import pandas as pd

# %%
data = pd.read_csv("matches.csv")

# %%
data.head(2)
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
#
#    result  dl_applied                 winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Kolkata Knight Riders          140               0
# 1  normal           0    Chennai Super Kings           33               0
#
#   player_of_match                                       venue    umpire1  \
# 0     BB McCullum                       M Chinnaswamy Stadium  Asad Rauf
# 1      MEK Hussey  Punjab Cricket Association Stadium, Mohali  MR Benson
#
#        umpire2  umpire3
# 0  RE Koertzen      NaN
# 1   SL Shastri      NaN

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
len(data)
# Out:
# 577

# %%
data.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
#data = data[['season','winner']].drop_duplicates('season',keep="last")

# %%
#print(data)

# %%
data[data['win_by_runs']>50][["team1","team2","win_by_runs"]]
# Out:
#                            team1                        team2  win_by_runs
# 0          Kolkata Knight Riders  Royal Challengers Bangalore          140
# 9                Kings XI Punjab               Mumbai Indians           66
# 41              Rajasthan Royals  Royal Challengers Bangalore           65
# 55              Rajasthan Royals             Delhi Daredevils          105
# 59   Royal Challengers Bangalore             Rajasthan Royals           75
# 62           Chennai Super Kings  Royal Challengers Bangalore           92
# 72                Mumbai Indians        Kolkata Knight Riders           92
# 84           Chennai Super Kings              Deccan Chargers           78
# 85              Rajasthan Royals              Kings XI Punjab           78
# 95               Deccan Chargers             Rajasthan Royals           53
# 122          Chennai Super Kings        Kolkata Knight Riders           55
# ...

# %%
len(data)
# Out:
# 577

# %%
#data.dropna(axis=1,inplace=True)
# row wise
